# %%
# import all the necessary libraries
import pysindy as ps
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("C://Users/user/documents/SINDY/ROM_data.csv")
data = data.values
omega = 1.1310
t = data[:,0]
tcat = np.expand_dims(t,axis=1)
x = data[:,1:5]
x = np.hstack((x, omega * tcat))
x0 = [0.001, 0, 0.001, 0, 0]
print(x[:,0])
# Out:
# [ 6.09541827e-11  1.78849515e-10  3.01979851e-10 ... -3.37571593e-07
#  -3.42462246e-07 -3.45870481e-07]

# %%
# The feature names of the columns of y
feature_names = ['x1', 'x2',"q1","q2", "omega t"]

# Which feature library to use
# Here I'm using a polynomial library that contains all combinations of the columns upto the degree 3

poly_lib = ps.PolynomialLibrary(degree=4)
fourier_lib = ps.FourierLibrary()

inputs_temp = np.tile([0, 1, 2, 3, 4], 2)
inputs_per_library = np.reshape(inputs_temp, (2,5))

inputs_per_library[0,4] = 0
inputs_per_library[1,0] = 4
inputs_per_library[1,1] = 4
inputs_per_library[1,2] = 4
inputs_per_library[1,3] = 4
inputs_per_library[1,4] = 4

print(inputs_per_library)

generalized_library = ps.GeneralizedLibrary(
    [poly_lib, fourier_lib],
inputs_per_library = inputs_per_library)

# Differentiation method
differentiation_method = ps.SmoothedFiniteDifference()


# Optimizer
opt = ps.STLSQ(threshold=0.01)

# Building the model
model=ps.SINDy(differentiation_method=differentiation_method,
               feature_library = generalized_library,
               feature_names=feature_names, 
              optimizer=opt)

# Fitting the model to the training data
model.fit(x,t=t)

# Print the model
model.print()
# Out:
# [[0 1 2 3 0]
#  [4 4 4 4 4]]
# (x1)' = 0.000
# (x2)' = 0.000
# (q1)' = 0.999 q2
# (q2)' = -1.431 q1 + 0.285 q2 + -0.284 q1^2 q2
# (omega t)' = 1.131 1
# C:\Users\user\anaconda3\lib\site-packages\pysindy\optimizers\stlsq.py:201: UserWarning: Sparsity parameter is too big (0.01) and eliminated all coefficients
#   warnings.warn(

# %%
# Simulate the identified system 
sim = model.simulate(x0,t=t)

# %%
# plot the solution

plt.rcParams.update({'font.size': 12})

# displacement
plt.plot(t,x[:,3],'r',alpha=0.7,linewidth=2.5, label="Original Signal")
plt.plot(t,sim[:,3],'k--',linewidth=2.5,label="Identified Signal")
plt.xlabel("t")
plt.ylabel("q")
plt.legend()
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.5)

plt.show()

# velocity
plt.plot(t,x[:,4],'r',alpha=0.7,linewidth=2.5, label="Original Signal")
plt.plot(t,sim[:,4],'k--',linewidth=2.5,label="Identified Signal")
plt.xlabel("t")
plt.ylabel("qdot")
plt.legend()
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.5)

plt.show()

# Error
plt.plot(t, np.abs(sim[:,0]-x[:,0]))
plt.title("Error")
plt.xlabel("t")
plt.ylabel("Error")
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.5)

plt.show()

# %%
print(x)
# Out:
# [[ 6.09541827e-11  2.12712208e-09  9.98221107e-04 -7.14048273e-05
#    5.65500000e-02]
#  [ 1.78849515e-10  3.77590318e-09  9.92835325e-04 -1.43740496e-04
#    1.13100000e-01]
#  [ 3.01979851e-10  2.45771610e-09  9.83793840e-04 -2.17559086e-04
#    1.69650000e-01]
#  ...
#  [-3.37571593e-07 -1.12941372e-07 -1.94762827e+00 -5.76986373e-01
#    1.69536900e+02]
#  [-3.42462246e-07 -8.22994313e-08 -1.97244354e+00 -4.16303238e-01
#    1.69593450e+02]
#  [-3.45870481e-07 -5.43916457e-08 -1.98933508e+00 -2.60197640e-01
#    1.69650000e+02]]
